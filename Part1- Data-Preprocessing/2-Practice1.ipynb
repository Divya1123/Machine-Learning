# %% [markdown]
# ### Project - Here we have dataset of retail company which consist of customer country, age, salary and if they purchased their product or not.

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing the Dataset
#
# - iloc for slicing
# - using .values we are returning numpy array instead of dataframe by removing col name and index.
# <br> Some ML libraries uses numpy instead of df

# %%
# creating dataframe named dataset
dataset = pd.read_csv('Data.csv')

X = dataset.iloc[:, :-1].values
Y = dataset.iloc[:, -1].values

# %%
print(X)
print('\n',Y)
# Out:
# [['France' 44.0 72000.0]
#  ['Spain' 27.0 48000.0]
#  ['Germany' 30.0 54000.0]
#  ['Spain' 38.0 61000.0]
#  ['Germany' 40.0 nan]
#  ['France' 35.0 58000.0]
#  ['Spain' nan 52000.0]
#  ['France' 48.0 79000.0]
#  ['Germany' 50.0 83000.0]
#  ['France' 37.0 67000.0]]
#
#  ['No' 'Yes' 'No' 'No' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes']

# %% [markdown]
# ### Handling Missing data
# - Missing data can cause error while training the ML models

# %% [markdown]
# ### Encoding categorical Data
#
# 1- Encoding Independent variable
# 2- Encoding dependent variable

# %% [markdown]
# ### Splitting data into test train dataset

# %% [markdown]
# ### Feature Scaling
